# %% [markdown]
# <a href="https://colab.research.google.com/github/estagiariodaford/AtividadesDoCursoPandas/blob/main/Segundo_exemplo_em_Python_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Segundo exemplo de manipulação de dados usando Python Pandas**
#
# Veremos inserção de dados, remoção de colunas, merge, gráficos
#
# Autor: Guilherme Bacelar
#
# Data: 9 e 10 de fevereiro de 2023
# "NOVO NOTEBOOK"

# %%
# Importando biblioteca pandas no Python
import pandas as pd

# %%
combustiveis_df = pd.read_excel("ca-2021-02.xlsx")
display(combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# 0  57302-605            GASOLINA     2021-11-01           6.799
# 1  57302-605              ETANOL     2021-11-01           5.299
# 2  57302-605              DIESEL     2021-11-01           5.549
# 3  57302-605  GASOLINA ADITIVADA     2021-11-01           6.899
# 4  57302-605          DIESEL S10     2021-11-01           5.649
#
#    Valor de Compra Unidade de Medida       Bandeira
# 0              NaN        R$ / litro  VIBRA ENERGIA
# 1              NaN        R$ / litro  VIBRA ENERGIA
# 2              NaN        R$ / litro  VIBRA ENERGIA
# 3              NaN        R$ / litro  VIBRA ENERGIA
# 4              NaN        R$ / litro  VIBRA ENERGIA

# %%
#Inserção simples de dados
combustiveis_df['Ativo'] = True

display(combustiveis_df.head())
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio               Revenda  \
# 0             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 1             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 2             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 3             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
# 4             NE             AL  ARAPIRACA  POSTO ARAPIRACA LTDA
#
#        CNPJ da Revenda     Nome da Rua Numero Rua Complemento       Bairro  \
# 0   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 1   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 2   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 3   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
# 4   12.451.076/0004-65  RODOVIA AL 220        105       KM 68  CANAFISTULA
#
#          Cep             Produto Data da Coleta  Valor de Venda  \
# 0  57302-605            GASOLINA     2021-11-01           6.799
# 1  57302-605              ETANOL     2021-11-01           5.299
# 2  57302-605              DIESEL     2021-11-01           5.549
# 3  57302-605  GASOLINA ADITIVADA     2021-11-01           6.899
# 4  57302-605          DIESEL S10     2021-11-01           5.649
#
#    Valor de Compra Unidade de Medida       Bandeira  Ativo
# 0              NaN        R$ / litro  VIBRA ENERGIA   True
# 1              NaN        R$ / litro  VIBRA ENERGIA   True
# 2              NaN        R$ / litro  VIBRA ENERGIA   True
# 3              NaN        R$ / litro  VIBRA ENERGIA   True
# 4              NaN        R$ / litro  VIBRA ENERGIA   True

# %%
#Criar uma coluna "Obs" que tenha nela escrito "MELHOR CIDADE" quando a coluna Municipio for igual a SALVADOR
combustiveis_df["Obs"] = ["MELHOR CIDADE" if municipio == "SALVADOR" else "" for municipio in combustiveis_df['Municipio']]
display(combustiveis_df.loc[combustiveis_df['Municipio'].isin(["SALVADOR", "JEQUIE"])])
# Out:
#        Regiao - Sigla Estado - Sigla Municipio  \
# 66                 NE             BA  SALVADOR
# 67                 NE             BA  SALVADOR
# 68                 NE             BA  SALVADOR
# 69                 NE             BA  SALVADOR
# 70                 NE             BA  SALVADOR
# ...               ...            ...       ...
# 168390             NE             BA    JEQUIE
# 168391             NE             BA    JEQUIE
# 168402             NE             BA    JEQUIE
# 168403             NE             BA    JEQUIE
# 168404             NE             BA    JEQUIE
#
#                                                   Revenda  \
# 66                       MP COMERCIO DE COMBUSTIVEIS LTDA
# 67                       MP COMERCIO DE COMBUSTIVEIS LTDA
# 68                       MP COMERCIO DE COMBUSTIVEIS LTDA
# 69                       MP COMERCIO DE COMBUSTIVEIS LTDA
# 70                       MP COMERCIO DE COMBUSTIVEIS LTDA
# ...                                                   ...
# 168390  M W COMERCIO DE COMBUSTIVEIS SERVICOS E ALIMEN...
# 168391  M W COMERCIO DE COMBUSTIVEIS SERVICOS E ALIMEN...
# 168402         COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168403         COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
# 168404         COMERCIAL DE COMBUSTIVEL CACHOEIRINHA LTDA
#
#             CNPJ da Revenda                           Nome da Rua Numero Rua  \
# 66       09.149.936/0001-53                      RUA DJALMA DUTRA        119
# 67       09.149.936/0001-53                      RUA DJALMA DUTRA        119
# 68       09.149.936/0001-53                      RUA DJALMA DUTRA        119
# 69       09.149.936/0003-15           AVENIDA MARIO LEAL FERREIRA        252
# 70       09.149.936/0003-15           AVENIDA MARIO LEAL FERREIRA        252
# ...                     ...                                   ...        ...
# 168390   00.697.413/0002-58  AVENIDA GOVERNADOR OTAVIO MANGABEIRA        153
# 168391   00.697.413/0002-58  AVENIDA GOVERNADOR OTAVIO MANGABEIRA        153
# 168402   28.629.089/0001-79             AVENIDA T LOT JD TROPICAL         53
# 168403   28.629.089/0001-79             AVENIDA T LOT JD TROPICAL         53
# 168404   28.629.089/0001-79             AVENIDA T LOT JD TROPICAL         53
#
#        Complemento     Bairro        Cep             Produto Data da Coleta  \
# 66             NaN     NAZARÉ  40255-000            GASOLINA     2021-11-01
# 67             NaN     NAZARÉ  40255-000              ETANOL     2021-11-01
# 68             NaN     NAZARÉ  40255-000  GASOLINA ADITIVADA     2021-11-01
# 69             NaN     BROTAS  40285-600            GASOLINA     2021-11-01
# 70             NaN     BROTAS  40285-600              ETANOL     2021-11-01
# ...            ...        ...        ...                 ...            ...
# 168390     ANEXO A  MANDACARU  45210-144              ETANOL     2021-12-31
# 168391     ANEXO A  MANDACARU  45210-144          DIESEL S10     2021-12-31
# 168402         NaN   TROPICAL  45209-130              DIESEL     2021-12-31
# 168403         NaN   TROPICAL  45209-130            GASOLINA     2021-12-31
# 168404         NaN   TROPICAL  45209-130              ETANOL     2021-12-31
#
#         Valor de Venda  Valor de Compra Unidade de Medida    Bandeira  Ativo  \
# 66               6.630              NaN        R$ / litro      BRANCA   True
# 67               5.630              NaN        R$ / litro      BRANCA   True
# 68               6.630              NaN        R$ / litro      BRANCA   True
# 69               6.630              NaN        R$ / litro      BRANCA   True
# 70               5.630              NaN        R$ / litro      BRANCA   True
# ...                ...              ...               ...         ...    ...
# 168390           5.599              NaN        R$ / litro      BRANCA   True
# 168391           5.449              NaN        R$ / litro      BRANCA   True
# 168402           5.499              NaN        R$ / litro  PETROSERRA   True
# 168403           6.799              NaN        R$ / litro  PETROSERRA   True
# 168404           5.859              NaN        R$ / litro  PETROSERRA   True
#
#                   Obs
# 66      MELHOR CIDADE
# 67      MELHOR CIDADE
# 68      MELHOR CIDADE
# 69      MELHOR CIDADE
# 70      MELHOR CIDADE
# ...               ...
# 168390
# 168391
# 168402
# 168403
# 168404
#
# [3220 rows x 18 columns]

# %%
#Calcular postos de gasolina por habitante temos na amostragem de 
#combustiveis nov/2021

num_habitantes_df = pd.read_csv("ibge_num_habitantes_estimado.csv", sep=";")
display(num_habitantes_df)
# Out:
#          Municipio Estado  NumHabitantes2021
# 0   BELO HORIZONTE     MG            2530701
# 1         CAMPINAS     SP            1223237
# 2     CAMPO GRANDE     MS             916001
# 3         CURITIBA     PR            1963726
# 4          GOIANIA     GO            1555626
# 5       INDAIATUBA     SP             260690
# 6            NATAL     RN             803739
# 7           PALMAS     TO             313349
# 8        PENAPOLIS     SP              64098
# 9     PORTO ALEGRE     RS            1492530
# 10     PORTO VELHO     RO             548952
# 11      RIO BRANCO     AC             419452
# 12  RIO DE JANEIRO     RJ            6775561
# 13    SALTO GRANDE     SP               9396
# 14          SANTOS     SP             433991
# 15       SAO PAULO     SP           12396372
# 16     SAO VICENTE     SP             370839
# 17     SERRA NEGRA     SP              29669

# %%
#Calcular postos de gasolina por habitante temos na amostragem de 
#combustiveis nov/2021

num_habitantes_df = pd.read_csv("ibge_num_habitantes_estimado.csv", sep=";")
num_habitantes_df.rename(columns={"Estado":"Estado - Sigla"}, inplace=True)
display(num_habitantes_df)
# Out:
#          Municipio Estado - Sigla  NumHabitantes2021
# 0   BELO HORIZONTE             MG            2530701
# 1         CAMPINAS             SP            1223237
# 2     CAMPO GRANDE             MS             916001
# 3         CURITIBA             PR            1963726
# 4          GOIANIA             GO            1555626
# 5       INDAIATUBA             SP             260690
# 6            NATAL             RN             803739
# 7           PALMAS             TO             313349
# 8        PENAPOLIS             SP              64098
# 9     PORTO ALEGRE             RS            1492530
# 10     PORTO VELHO             RO             548952
# 11      RIO BRANCO             AC             419452
# 12  RIO DE JANEIRO             RJ            6775561
# 13    SALTO GRANDE             SP               9396
# 14          SANTOS             SP             433991
# 15       SAO PAULO             SP           12396372
# 16     SAO VICENTE             SP             370839
# 17     SERRA NEGRA             SP              29669

# %%
#Faz um MERGE dos dois dataframes
colunas = ['Municipio', 'Estado - Sigla']
merge_df = combustiveis_df.merge(num_habitantes_df, how="inner", on=colunas)
display(merge_df)
# Out:
#       Regiao - Sigla Estado - Sigla   Municipio  \
# 0                 CO             GO     GOIANIA
# 1                 CO             GO     GOIANIA
# 2                 CO             GO     GOIANIA
# 3                 CO             GO     GOIANIA
# 4                 CO             GO     GOIANIA
# ...              ...            ...         ...
# 20629             SE             SP  INDAIATUBA
# 20630             SE             SP  INDAIATUBA
# 20631             SE             SP  INDAIATUBA
# 20632             SE             SP  INDAIATUBA
# 20633             SE             SP  INDAIATUBA
#
#                                          Revenda      CNPJ da Revenda  \
# 0                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 1                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 2                      AERO SETE AUTO POSTO LTDA   37.831.484/0001-20
# 3                              POSTO DO BOI LTDA   06.880.293/0001-25
# 4                              POSTO DO BOI LTDA   06.880.293/0001-25
# ...                                          ...                  ...
# 20629                     POSTO DOS ESTEVES LTDA   20.763.169/0001-00
# 20630  ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA   30.253.289/0001-11
# 20631  ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA   30.253.289/0001-11
# 20632  ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA   30.253.289/0001-11
# 20633  ABDELNOR VI COMERCIO DE COMBUSTIVEIS LTDA   30.253.289/0001-11
#
#                           Nome da Rua Numero Rua  \
# 0      AVENIDA VEREADOR JOSE MONTEIRO       1854
# 1      AVENIDA VEREADOR JOSE MONTEIRO       1854
# 2      AVENIDA VEREADOR JOSE MONTEIRO       1854
# 3               AVENIDA INDEPENDENCIA      2.908
# 4               AVENIDA INDEPENDENCIA      2.908
# ...                               ...        ...
# 20629                 AVENIDA ITORORO        160
# 20630      AVENIDA PRESIDENTE KENNEDY        496
# 20631      AVENIDA PRESIDENTE KENNEDY        496
# 20632      AVENIDA PRESIDENTE KENNEDY        496
# 20633      AVENIDA PRESIDENTE KENNEDY        496
#
#                                Complemento                Bairro        Cep  \
# 0      QUADRA08                  LOTE  11E  SETOR NEGRAO DE LIMA  74650-300
# 1      QUADRA08                  LOTE  11E  SETOR NEGRAO DE LIMA  74650-300
# 2      QUADRA08                  LOTE  11E  SETOR NEGRAO DE LIMA  74650-300
# 3                                      NaN             VILA NOVA  74645-010
# 4                                      NaN             VILA NOVA  74645-010
# ...                                    ...                   ...        ...
# 20629                                  NaN                CENTRO  13330-055
# 20630                                  NaN         CIDADE NOVA I  13334-170
# 20631                                  NaN         CIDADE NOVA I  13334-170
# 20632                                  NaN         CIDADE NOVA I  13334-170
# 20633                                  NaN         CIDADE NOVA I  13334-170
#
#                   Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 0                GASOLINA     2021-11-01           6.999              NaN
# 1                  ETANOL     2021-11-01           4.990              NaN
# 2      GASOLINA ADITIVADA     2021-11-01           7.130              NaN
# 3                GASOLINA     2021-11-01           6.990              NaN
# 4                  ETANOL     2021-11-01           4.990              NaN
# ...                   ...            ...             ...              ...
# 20629            GASOLINA     2021-12-28           6.499              NaN
# 20630          DIESEL S10     2021-12-28           5.499              NaN
# 20631  GASOLINA ADITIVADA     2021-12-28           6.699              NaN
# 20632              ETANOL     2021-12-28           4.899              NaN
# 20633            GASOLINA     2021-12-28           6.299              NaN
#
#       Unidade de Medida  Bandeira  Ativo Obs  NumHabitantes2021
# 0            R$ / litro    RAIZEN   True                1555626
# 1            R$ / litro    RAIZEN   True                1555626
# 2            R$ / litro    RAIZEN   True                1555626
# 3            R$ / litro    BRANCA   True                1555626
# 4            R$ / litro    BRANCA   True                1555626
# ...                 ...       ...    ...  ..                ...
# 20629        R$ / litro  IPIRANGA   True                 260690
# 20630        R$ / litro    RAIZEN   True                 260690
# 20631        R$ / litro    RAIZEN   True                 260690
# 20632        R$ / litro    RAIZEN   True                 260690
# 20633        R$ / litro    RAIZEN   True                 260690
#
# [20634 rows x 19 columns]

# %%
#Eliminar colunas completamente vazias (linhas são nulas)
merge_df.dropna(axis='columns', inplace=True)
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Regiao - Sigla     20634 non-null  object
#  1   Estado - Sigla     20634 non-null  object
#  2   Municipio          20634 non-null  object
#  3   Revenda            20634 non-null  object
#  4   CNPJ da Revenda    20634 non-null  object
#  5   Nome da Rua        20634 non-null  object
#  6   Numero Rua         20634 non-null  object
#  7   Bairro             20634 non-null  object
#  8   Cep                20634 non-null  object
#  9   Produto            20634 non-null  object
#  10  Data da Coleta     20634 non-null  datetime64[ns]
#  11  Valor de Venda     20634 non-null  float64
#  12  Unidade de Medida  20634 non-null  object
#  13  Bandeira           20634 non-null  object
#  14  Ativo              20634 non-null  bool
#  15  Obs                20634 non-null  object
#  16  NumHabitantes2021  20634 non-null  int64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(1), object(13)
# memory usage: 2.7+ MB
# None

# %%
colunas=['Regiao - Sigla', 'Nome da Rua', 'Numero Rua', 
         'Bairro', 'Cep', 'Produto', 'Data da Coleta',
         'Unidade de Medida', 'Bandeira', 'Ativo']
merge_df.drop(labels=colunas, axis=1, inplace=True)
print(merge_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20634 entries, 0 to 20633
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Estado - Sigla     20634 non-null  object
#  1   Municipio          20634 non-null  object
#  2   Revenda            20634 non-null  object
#  3   CNPJ da Revenda    20634 non-null  object
#  4   Valor de Venda     20634 non-null  float64
#  5   Obs                20634 non-null  object
#  6   NumHabitantes2021  20634 non-null  int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.3+ MB
# None

# %%
#Eliminação de linhas duplicadas
merge_df.drop_duplicates(inplace=True)
display(merge_df.head(100))
# Out:
#     Estado - Sigla Municipio                       Revenda  \
# 0               GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 1               GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 2               GO   GOIANIA     AERO SETE AUTO POSTO LTDA
# 3               GO   GOIANIA             POSTO DO BOI LTDA
# 4               GO   GOIANIA             POSTO DO BOI LTDA
# ..             ...       ...                           ...
# 98              GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
# 99              GO   GOIANIA  AUTO POSTO ANTENA 104 EIRELI
# 100             GO   GOIANIA          POSTO TASSARA EIRELI
# 101             GO   GOIANIA          POSTO TASSARA EIRELI
# 102             GO   GOIANIA          POSTO TASSARA EIRELI
#
#          CNPJ da Revenda  Valor de Venda Obs  NumHabitantes2021
# 0     37.831.484/0001-20           6.999                1555626
# 1     37.831.484/0001-20           4.990                1555626
# 2     37.831.484/0001-20           7.130                1555626
# 3     06.880.293/0001-25           6.990                1555626
# 4     06.880.293/0001-25           4.990                1555626
# ..                   ...             ...  ..                ...
# 98    05.634.368/0001-25           7.190                1555626
# 99    05.634.368/0001-25           5.990                1555626
# 100   07.021.139/0001-60           5.190                1555626
# 101   07.021.139/0001-60           5.490                1555626
# 102   07.021.139/0001-60           7.190                1555626
#
# [100 rows x 7 columns]

# %%
#Agrupar e contar quantos postos tem na cidade:
postos_por_municipio_df = merge_df.groupby(by=['Estado - Sigla', 'Municipio', 'NumHabitantes2021']).count()
postos_por_municipio_df.drop('CNPJ da Revenda', axis=1, inplace=True)
postos_por_municipio_df.rename(columns={"Revenda": "Número de Postos"}, inplace=True)
display(postos_por_municipio_df)
# Out:
#                                                  Número de Postos  \
# Estado - Sigla Municipio      NumHabitantes2021
# AC             RIO BRANCO     419452                          268
# GO             GOIANIA        1555626                         923
# MG             BELO HORIZONTE 2530701                         452
# MS             CAMPO GRANDE   916001                          791
# PR             CURITIBA       1963726                         742
# RJ             RIO DE JANEIRO 6775561                        2037
# RN             NATAL          803739                          423
# RO             PORTO VELHO    548952                          224
# RS             PORTO ALEGRE   1492530                         439
# SP             CAMPINAS       1223237                         501
#                INDAIATUBA     260690                          263
#                SANTOS         433991                          219
#                SAO PAULO      12396372                       2587
#                SAO VICENTE    370839                          148
# TO             PALMAS         313349                          131
#
#                                                  Valor de Venda   Obs
# Estado - Sigla Municipio      NumHabitantes2021
# AC             RIO BRANCO     419452                        268   268
# GO             GOIANIA        1555626                       923   923
# MG             BELO HORIZONTE 2530701                       452   452
# MS             CAMPO GRANDE   916001                        791   791
# PR             CURITIBA       1963726                       742   742
# RJ             RIO DE JANEIRO 6775561                      2037  2037
# RN             NATAL          803739                        423   423
# RO             PORTO VELHO    548952                        224   224
# RS             PORTO ALEGRE   1492530                       439   439
# SP             CAMPINAS       1223237                       501   501
#                INDAIATUBA     260690                        263   263
#                SANTOS         433991                        219   219
#                SAO PAULO      12396372                     2587  2587
#                SAO VICENTE    370839                        148   148
# TO             PALMAS         313349                        131   131

# %%
#Agrupar e contar quantos postos tem na cidade:
postos_por_municipio_df = merge_df.groupby(by=['Estado - Sigla', 'Municipio', "NumHabitantes2021"]).count()
postos_por_municipio_df.drop('CNPJ da Revenda', axis=1, inplace=True)
postos_por_municipio_df.reset_index(inplace=True)
postos_por_municipio_df.rename(columns={"Revenda":"Numero de Postos"}, inplace=True)
display(postos_por_municipio_df)
postos_por_municipio_df['PostosPorHabitane'] = postos_por_municipio_df['Numero de Postos'] / postos_por_municipio_df['NumHabitantes2021']
display(postos_por_municipio_df)
# Out:
#    Estado - Sigla       Municipio  NumHabitantes2021  Numero de Postos  \
# 0              AC      RIO BRANCO             419452               268
# 1              GO         GOIANIA            1555626               923
# 2              MG  BELO HORIZONTE            2530701               452
# 3              MS    CAMPO GRANDE             916001               791
# 4              PR        CURITIBA            1963726               742
# 5              RJ  RIO DE JANEIRO            6775561              2037
# 6              RN           NATAL             803739               423
# 7              RO     PORTO VELHO             548952               224
# 8              RS    PORTO ALEGRE            1492530               439
# 9              SP        CAMPINAS            1223237               501
# 10             SP      INDAIATUBA             260690               263
# 11             SP          SANTOS             433991               219
# 12             SP       SAO PAULO           12396372              2587
# 13             SP     SAO VICENTE             370839               148
# 14             TO          PALMAS             313349               131
#
#     Valor de Venda   Obs
# 0              268   268
# 1              923   923
# 2              452   452
# 3              791   791
# 4              742   742
# 5             2037  2037
# 6              423   423
# 7              224   224
# 8              439   439
# 9              501   501
# 10             263   263
# 11             219   219
# 12            2587  2587
# 13             148   148
# 14             131   131
#    Estado - Sigla       Municipio  NumHabitantes2021  Numero de Postos  \
# 0              AC      RIO BRANCO             419452               268
# 1              GO         GOIANIA            1555626               923
# 2              MG  BELO HORIZONTE            2530701               452
# 3              MS    CAMPO GRANDE             916001               791
# 4              PR        CURITIBA            1963726               742
# 5              RJ  RIO DE JANEIRO            6775561              2037
# 6              RN           NATAL             803739               423
# 7              RO     PORTO VELHO             548952               224
# 8              RS    PORTO ALEGRE            1492530               439
# 9              SP        CAMPINAS            1223237               501
# 10             SP      INDAIATUBA             260690               263
# 11             SP          SANTOS             433991               219
# 12             SP       SAO PAULO           12396372              2587
# 13             SP     SAO VICENTE             370839               148
# 14             TO          PALMAS             313349               131
#
#     Valor de Venda   Obs  PostosPorHabitane
# 0              268   268           0.000639
# 1              923   923           0.000593
# 2              452   452           0.000179
# 3              791   791           0.000864
# 4              742   742           0.000378
# 5             2037  2037           0.000301
# 6              423   423           0.000526
# 7              224   224           0.000408
# 8              439   439           0.000294
# 9              501   501           0.000410
# 10             263   263           0.001009
# 11             219   219           0.000505
# 12            2587  2587           0.000209
# 13             148   148           0.000399
# 14             131   131           0.000418

# %%
#Agrupar e contar quantos postos tem na cidade..
postos_por_municipio_df = merge_df.groupby(by=['Estado - Sigla', 'Municipio', 'NumHabitantes2021']).count()
postos_por_municipio_df.reset_index(inplace=True)

#display(postos_por_municipio_df.info())
postos_por_municipio_df.drop('CNPJ da Revenda', axis=1, inplace=True)
postos_por_municipio_df.rename(columns={"Revenda": "NumPostos"}, inplace=True)
postos_por_municipio_df['NumHabitantesPorPosto'] = postos_por_municipio_df['NumHabitantes2021'] / postos_por_municipio_df['NumPostos']

#display(postos_por_municipio_df.info())
display(postos_por_municipio_df)
# Out:
#    Estado - Sigla       Municipio  NumHabitantes2021  NumPostos  \
# 0              AC      RIO BRANCO             419452        268
# 1              GO         GOIANIA            1555626        923
# 2              MG  BELO HORIZONTE            2530701        452
# 3              MS    CAMPO GRANDE             916001        791
# 4              PR        CURITIBA            1963726        742
# 5              RJ  RIO DE JANEIRO            6775561       2037
# 6              RN           NATAL             803739        423
# 7              RO     PORTO VELHO             548952        224
# 8              RS    PORTO ALEGRE            1492530        439
# 9              SP        CAMPINAS            1223237        501
# 10             SP      INDAIATUBA             260690        263
# 11             SP          SANTOS             433991        219
# 12             SP       SAO PAULO           12396372       2587
# 13             SP     SAO VICENTE             370839        148
# 14             TO          PALMAS             313349        131
#
#     Valor de Venda   Obs  NumHabitantesPorPosto
# 0              268   268            1565.119403
# 1              923   923            1685.401950
# 2              452   452            5598.896018
# 3              791   791            1158.029077
# 4              742   742            2646.530997
# 5             2037  2037            3326.244968
# 6              423   423            1900.092199
# 7              224   224            2450.678571
# 8              439   439            3399.840547
# 9              501   501            2441.590818
# 10             263   263             991.216730
# 11             219   219            1981.694064
# 12            2587  2587            4791.794356
# 13             148   148            2505.668919
# 14             131   131            2391.977099

# %%
#Vamos brincar de gráficos!!!

import matplotlib.pyplot as plt
plt.hist(combustiveis_df['Valor de Venda'])

#Vamos colocar um título no gráfico
plt.title("Preço dos combustíveis Nov/2021")

#Rótulo horizontal 
plt.xlabel("Preço (em reais)")
plt.ylabel("Quantidade de Coletas")

#Traça a linha vermelha tracejada com o preço médio
plt.axvline(combustiveis_df['Valor de Venda'].mean(), color='red', linestyle='dashed', linewidth=2)

#"Plota" o gráfico
plt.show()

# %%
#Segundo gráfico
c_mean = combustiveis_df['Valor de Venda'].groupby(by=combustiveis_df['Produto']).mean()
display(c_mean)
# Out:
# Produto
# DIESEL                5.375682
# DIESEL S10            5.454901
# ETANOL                5.456115
# GASOLINA              6.708741
# GASOLINA ADITIVADA    6.860422
# GNV                   4.392935
# Name: Valor de Venda, dtype: float64

# %%
import seaborn as sns

#Escala do gráfico
plt.figure(figsize=(10, 5))

#Plotagem do gráfico
c_mean_grafico = c_mean.plot(
    kind="barh",
    title= "Média Preço por Combustiveis",
    xlabel="Tipo de Combustivel",
    ylabel="Preço reais/litro",
    color="red",
    alpha = 0.9,
)

c_mean_grafico.set_ylabel("Tipo de Combustivel")
c_mean_grafico.set_xlabel("Preço reais/litro")

plt.grid(axis="x")

sns.despine(right=False, bottom=True)

plt.show()

# %%
#c_mean.reset_index(inplace=True)
display(c_mean)

excel = "por_litro.xlsx"
c_mean.to_excel(excel, "Sumário")
# Out:
# Produto
# DIESEL                5.375682
# DIESEL S10            5.454901
# ETANOL                5.456115
# GASOLINA              6.708741
# GASOLINA ADITIVADA    6.860422
# GNV                   4.392935
# Name: Valor de Venda, dtype: float64

# %%
#Personalização de planilha Excel...
from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Color, Alignment

#Vai abrir o Excel no openpyxl
wb = load_workbook(excel) # wb = Workbook

#Pegar a planilha certa... usando o Sheet Name (nome da planilha)
ws = wb['Sumário'] #Obs.: Work Sheet -> planilha atual, ativa, de trabalho

#Para pintar o cabeçalho da tabela de "cinza"
cinzinha = PatternFill("solid", fgColor="CCCCCC")
coords = ['A1', 'B1']
for coord in coords:
  ws[coord].fill = cinzinha

# Onde o preço do combustível for maior ou igual a 6,5 reais (6.5) pinta a fonte
# de vermelho e deixa negrito...
MAX_ROW = ws.max_row
num_linha = 2
while (num_linha <= MAX_ROW):
  coord="B{0}".format(num_linha)
  if ws[coord].value >= 6.5:
    ws[coord].font = Font(bold=True, color="FF0000")
  num_linha = num_linha + 1

#Para salvar o Excel
wb.save(excel)
